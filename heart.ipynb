# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("heart.csv")

# print the first 5 rows of the dataframe
df.head(100)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# ..  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 95   53    1   0       142   226    0        0      111      1      0.0
# 96   62    0   0       140   394    0        0      157      0      1.2
# 97   52    1   0       108   233    1        1      147      0      0.1
# 98   43    1   2       130   315    0        1      162      0      1.9
# 99   53    1   2       130   246    1        0      173      0      0.0
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 1       0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 
        'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df['target']

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 124   39    0   2        94   199    0        1      179      0      0.0
# 72    29    1   1       130   204    0        0      202      0      0.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 163   38    1   2       138   175    0        1      173      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 188   50    1   2       140   233    0        1      163      0      0.6
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 270   46    1   0       120   249    0        0      144      0      0.8
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal
# 124      2   0     2
# 72       2   0     2
# 15       1   0     2
# ...

# %%
X_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 179   57    1   0       150   276    0        0      112      1      0.6
# 228   59    1   3       170   288    0        0      159      0      0.2
# 111   57    1   2       150   126    1        1      173      0      0.2
# 246   56    0   0       134   409    0        0      150      1      1.9
# 60    71    0   2       110   265    1        0      130      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 250   51    1   0       140   298    0        1      122      1      4.2
# 19    69    0   3       140   239    0        1      151      0      1.8
# 143   67    0   0       106   223    0        1      142      0      0.3
# 79    58    1   2       105   240    0        0      154      1      0.6
# 144   76    0   2       140   197    0        2      116      0      1.1
#
#      slope  ca  thal
# 179      1   1     1
# 228      1   0     3
# 111      2   1     3
# ...

# %%
# Initialize and train a RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Evaluate the model
accuracy = model.score(X_test, y_test)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.82

# %%
user_input = {
    'age': 53,
    'sex': 1,
    'cp': 0,
    'trestbps': 140,
    'chol': 203,
    'fbs': 1,
    'restecg': 0,
    'thalach': 155,
    'exang': 1,
    'oldpeak': 3.1,
    'slope': 0,
    'ca': 0,
    'thal': 3
}

# %%
import numpy as np

# Convert the user input dictionary to a 2D array
user_input_array = np.array([[user_input['age'], user_input['sex'], user_input['cp'], user_input['trestbps'], 
                              user_input['chol'], user_input['fbs'], user_input['restecg'], user_input['thalach'], 
                              user_input['exang'], user_input['oldpeak'], user_input['slope'], user_input['ca'], 
                              user_input['thal']]])

# %%
user_input_array
# Out:
# array([[ 53. ,   1. ,   0. , 140. , 203. ,   1. ,   0. , 155. ,   1. ,
#           3.1,   0. ,   0. ,   3. ]])

# %%
prediction = model.predict(user_input_array)

print(f'Predicted class: {prediction[0]}')

print(f'Predicted11 class: {prediction}')
# Out:
# Predicted class: 0
# Predicted11 class: [0]
# C:\Users\sanga\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if prediction[0]==0:
  print('no heart disease')
else:
  print('heart disease')
# Out:
# no heart disease
